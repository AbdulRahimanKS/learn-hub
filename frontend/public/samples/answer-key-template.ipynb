# %% [markdown]
# # Weekly Test Answer Key Template
#
# Use this file as a reference format.
# Include both questions and model answers in the same document.

# %% [markdown]
# ## Question 1
# Explain the difference between supervised and unsupervised learning.

# %% [markdown]
# ### Answer 1
# - Supervised learning uses labeled data.
# - Unsupervised learning uses unlabeled data to find patterns.
# - Examples: Classification/Regression vs Clustering/Dimensionality Reduction.

# %% [markdown]
# ## Question 2
# Write a Python function to compute factorial of n.

# %%
def factorial(n):
    if n < 0:
        raise ValueError('n must be non-negative')
    if n in (0, 1):
        return 1
    result = 1
    for i in range(2, n + 1):
        result *= i
    return result

# %% [markdown]
# ### Grading Notes
# - Question 1: check concepts and examples.
# - Question 2: verify correctness, edge-case handling, and readability.
