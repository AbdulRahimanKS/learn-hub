# %% [markdown]
# # Student Answer Solution Template
#
# Use this file to write your solution and upload it in the weekly assessment submission form.
#
# - Replace placeholders with your own work
# - Keep outputs concise
# - Save and upload this `.ipynb` file

# %% [markdown]
# ## Question 1
#
# Write your approach briefly before code.

# %%
# Write your answer for Question 1 here
def solution_q1():
    pass

solution_q1()

# %% [markdown]
# ## Question 2
#
# Add explanation and final result.

# %%
# Write your answer for Question 2 here
def solution_q2():
    pass

solution_q2()
